# %%
import pandas as pd

# data = pd.read_csv("/content/sample_data/IndianHouses.csv")
data = pd.read_csv('IndianHouses.csv')
data.head()
# Out:
#    Area  BHK  Bathroom      Furnishing  \
# 0   800    3         2  Semi-Furnished
# 1   750    2         2  Semi-Furnished
# 2   950    2         2       Furnished
# 3   600    2         2  Semi-Furnished
# 4   650    2         2  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25        1   6500000
# 1             J R Designers Floors, Rohini Sector 24        1   5000000
# 2                Citizen Apartment, Rohini Sector 13        1  15500000
# 3                                   Rohini Sector 24        1   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...        1   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor      4837
# 1  Ready_to_move  New_Property      Apartment      6667
# 2  Ready_to_move        Resale      Apartment      6667
# 3  Ready_to_move        Resale  Builder_Floor      6667
# 4  Ready_to_move  New_Property  Builder_Floor      6667

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   int64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1259 non-null   int64
#  3   Furnishing   1259 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1259 non-null   int64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1259 non-null   object
#  10  Per_Sqft     1259 non-null   int64
# dtypes: int64(6), object(5)
# memory usage: 108.3+ KB

# %%
data.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean    1466.452740     2.796664     2.553614     1.919778  2.130670e+07
# std     1568.054954     0.954425     1.043235     6.197908  2.560115e+07
# min       28.000000     1.000000     1.000000     0.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1259.000000
# mean    16095.737887
# std     22126.686354
# min      1259.000000
# 25%      6526.000000
# 50%     11538.000000
# 75%     18000.000000
# max    183333.000000

# %%
number_Of_Rows = len(data)
number_Of_Rows
# Out:
# 1259

# %%
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# dtype: int64

# %%
Missing_Values_Columns = ['Bathroom', 'Parking', 'Per_Sqft']
for column in Missing_Values_Columns:
    average_value = data[column].mean()
    data[column].fillna(average_value, inplace=True)

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# dtype: int64

# %%
String_Columns_Missing_Values = ['Furnishing', 'Type']
for column in String_Columns_Missing_Values:
  Most_Repetative_Value = data[column].mode()[0]
  data[column].fillna(Most_Repetative_Value, inplace = True)

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# dtype: int64

# %%
duplicate_rows = data.duplicated()
duplicate_rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1254    False
# 1255    False
# 1256    False
# 1257    False
# 1258    False
# Length: 1259, dtype: bool

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %% [markdown]
# #### Descriptive Statistics
# Centrality and Spread Measures for Quantitive variables
#
# - Measures of Central Tendency
#     - Mean
#     - Median
#     - Mode
#     - Percentiles
#     - Quartiles
#
# - Measures of Spread
#     - Range
#     - IQR
#     - Variance
#     - Standard Deviation

# %%
# 
data['Price'].describe().to_dict()
# Out:
# {'count': 1259.0,
#  'mean': 21306703.733121525,
#  'std': 25601154.525779802,
#  'min': 1000000.0,
#  '25%': 5700000.0,
#  '50%': 14200000.0,
#  '75%': 25500000.0,
#  'max': 240000000.0}

# %% [markdown]
# Mean = 21M
#
# Median = 14M

# %%
sns.histplot(data, x='Price', kde=True)
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: '{:,.0f}'.format(x * 1)))
plt.xticks(rotation=90)
plt.show()

# %%
data[data['Price']>100000000]
# Out:
#        Area  BHK  Bathroom      Furnishing  \
# 57     8000    4         5  Semi-Furnished
# 109    8000    4         5  Semi-Furnished
# 209    4688    5         4     Unfurnished
# 225    5025    5         6     Unfurnished
# 242    6000    5         5  Semi-Furnished
# 248   10350    4         7  Semi-Furnished
# 253    4200    5         5  Semi-Furnished
# 255    8150    4         5     Unfurnished
# 268    7200    4         4  Semi-Furnished
# 419    4688    5         4     Unfurnished
# 479    4688    5         4     Unfurnished
# 495    5025    5         6     Unfurnished
# 585    5500    6         7       Furnished
# 1126   4455    5         5  Semi-Furnished
# 1202   6000    5         5  Semi-Furnished
# 1210   6500    4         5     Unfurnished
# 1211   4350    4         6  Semi-Furnished
# 1224   5400    4         4     Unfurnished
# 1226   2300    4         4  Semi-Furnished
#
#                                                Locality  Parking      Price  \
# 57                                         Lajpat Nagar        1  240000000
# 109                                        Lajpat Nagar        1  240000000
# 209                   The Leela Sky Villas, Patel Nagar        1  135000000
# 225                                   Greater Kailash 2        4  170000000
# 242                   Maharani Bagh, New Friends Colony        9  220000000
# 248                   Maharani Bagh, New Friends Colony        3  160000000
# 253             Friends Colony East, New Friends Colony        2  135500000
# 255                   Maharani Bagh, New Friends Colony        4  170000000
# 268                   Maharani Bagh, New Friends Colony        2  120000000
# 419                   The Leela Sky Villas, Patel Nagar        1  135000000
# 479                   The Leela Sky Villas, Patel Nagar        1  135000000
# 495                                   Greater Kailash 2        4  170000000
# 585                                  Safdarjung Enclave        1  160000000
# 1126                                  Punjabi Bagh West        1  115000000
# 1202  Hauz Khas Apartment, Hauz Khas Enclave, Hauz Khas        3  180000000
# 1210                          Mayfair garden, Hauz Khas        3  190000000
# 1211                       Orchid Metropolis, Hauz Khas        2  135000000
# 1224                       Hauz Khas Enclave, Hauz Khas        2  110000000
# 1226                                          Hauz Khas        1  102500000
#
#              Status   Transaction           Type  Per_Sqft
# 57    Ready_to_move  New_Property  Builder_Floor     22000
# 109   Ready_to_move  New_Property  Builder_Floor     20000
# 209    Almost_ready  New_Property      Apartment     28797
# 225    Almost_ready  New_Property  Builder_Floor     22222
# 242   Ready_to_move  New_Property  Builder_Floor    120000
# 248   Ready_to_move  New_Property      Apartment     15459
# 253   Ready_to_move  New_Property  Builder_Floor     15459
# 255   Ready_to_move  New_Property  Builder_Floor     15459
# 268   Ready_to_move        Resale  Builder_Floor     16667
# 419    Almost_ready  New_Property      Apartment     28797
# 479    Almost_ready  New_Property      Apartment     28797
# 495    Almost_ready  New_Property  Builder_Floor     22222
# 585   Ready_to_move        Resale      Apartment     14818
# 1126   Almost_ready  New_Property  Builder_Floor     11905
# 1202  Ready_to_move  New_Property      Apartment     30000
# 1210  Ready_to_move  New_Property  Builder_Floor    170000
# 1211  Ready_to_move  New_Property      Apartment    170000
# 1224  Ready_to_move        Resale  Builder_Floor     17677
# 1226  Ready_to_move  New_Property  Builder_Floor     17677

# %% [markdown]
# And surprisingly, house having no. Of bedrooms = 10 is not present in the above results, so it doen’t affect more on the price.

# %%
data['BHK'].value_counts().sort_index()
# Out:
# BHK
# 1      96
# 2     367
# 3     541
# 4     220
# 5      27
# 6       6
# 7       1
# 10      1
# Name: count, dtype: int64

# %%
data[data['BHK']==10]
# Out:
#      Area  BHK  Bathroom      Furnishing  \
# 721  1200   10         4  Semi-Furnished
#
#                                               Locality  Parking     Price  \
# 721  DDA Flats Sarita Vihar, Sarita Vihar, Mathura ...        2  17000000
#
#             Status Transaction       Type  Per_Sqft
# 721  Ready_to_move      Resale  Apartment     11905

# %% [markdown]
# Area col

# %%
data['Area'].describe().to_dict()
# Out:
# {'count': 1259.0,
#  'mean': 1466.4527402700555,
#  'std': 1568.054953942464,
#  'min': 28.0,
#  '25%': 800.0,
#  '50%': 1200.0,
#  '75%': 1700.0,
#  'max': 24300.0}

# %%
sns.boxplot(data, x='Area')
# Out:
# <Axes: xlabel='Area'>

# %%
sns.histplot(data, x='Area', kde=True)
# Out:
# <Axes: xlabel='Area', ylabel='Count'>

# %%
data[data['Area']>10000]
# Out:
#        Area  BHK  Bathroom      Furnishing                           Locality  \
# 234   22050    4         4  Semi-Furnished                  Greater Kailash 1
# 248   10350    4         7  Semi-Furnished  Maharani Bagh, New Friends Colony
# 504   22050    4         4  Semi-Furnished                  Greater Kailash 1
# 567   24300    4         5  Semi-Furnished                              Saket
# 626   14220    3         3  Semi-Furnished             Paschim Vihar Block B4
# 1133  17010    3         3  Semi-Furnished                  Punjabi Bagh West
# 1258  11050    3         3     Unfurnished                  Chittaranjan Park
#
#       Parking      Price         Status   Transaction           Type  Per_Sqft
# 234         2   51000000   Almost_ready  New_Property  Builder_Floor     30556
# 248         3  160000000  Ready_to_move  New_Property      Apartment     15459
# 504         2   51000000   Almost_ready  New_Property  Builder_Floor     30556
# 567         2   51000000  Ready_to_move        Resale  Builder_Floor     12500
# 626         1   27500000  Ready_to_move  New_Property  Builder_Floor     10943
# 1133        2   25000000  Ready_to_move        Resale  Builder_Floor     15278
# 1258        1   18500000  Ready_to_move  New_Property  Builder_Floor     12916

# %% [markdown]
# Most of the houses with Area gt 10k sqft has pricesless than 100M

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['Price'], axis = 1)
y = data['Price']

# %%
x
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking  \
# 0                                      Rohini Sector 25      1.0
# 1                J R Designers Floors, Rohini Sector 24      1.0
# 2                   Citizen Apartment, Rohini Sector 13      1.0
# 3                                      Rohini Sector 24      1.0
# 4     Rohini Sector 24 carpet area 650 sqft status R...      1.0
# ...                                                 ...      ...
# 1254                                  Chittaranjan Park      3.0
# 1255                                  Chittaranjan Park      3.0
# 1256                                  Chittaranjan Park      3.0
# 1257                          Chittaranjan Park Block A      1.0
# 1258                                  Chittaranjan Park      1.0
#
#              Status   Transaction           Type      Per_Sqft
# 0     Ready_to_move  New_Property  Builder_Floor  15690.136542
# 1     Ready_to_move  New_Property      Apartment   6667.000000
# 2     Ready_to_move        Resale      Apartment   6667.000000
# 3     Ready_to_move        Resale  Builder_Floor   6667.000000
# 4     Ready_to_move  New_Property  Builder_Floor   6667.000000
# ...             ...           ...            ...           ...
# 1254  Ready_to_move  New_Property  Builder_Floor  12916.000000
# 1255  Ready_to_move        Resale  Builder_Floor  12916.000000
# 1256  Ready_to_move  New_Property  Builder_Floor  12916.000000
# 1257  Ready_to_move        Resale  Builder_Floor  12916.000000
# 1258  Ready_to_move  New_Property  Builder_Floor  12916.000000
#
# [1259 rows x 10 columns]

# %%
y
# Out:
# 0        6500000
# 1        5000000
# 2       15500000
# 3        4200000
# 4        6200000
#           ...
# 1254    55000000
# 1255    12500000
# 1256    17500000
# 1257    11500000
# 1258    18500000
# Name: Price, Length: 1259, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#         Area  BHK  Bathroom      Furnishing  \
# 40    1650.0    3       3.0  Semi-Furnished
# 118   1700.0    3       3.0     Unfurnished
# 598   2200.0    4       4.0  Semi-Furnished
# 426   2000.0    3       3.0  Semi-Furnished
# 287   1600.0    3       3.0     Unfurnished
# ...      ...  ...       ...             ...
# 1243  1650.0    3       3.0     Unfurnished
# 1153  2700.0    4       4.0     Unfurnished
# 462   1200.0    3       2.0  Semi-Furnished
# 870    450.0    1       1.0       Furnished
# 391   1000.0    3       2.0     Unfurnished
#
#                                                Locality  Parking  \
# 40                                         Lajpat Nagar      1.0
# 118                                      Lajpat Nagar 3      1.0
# 598   Safdarjung Enclave super area 2200 sqft status...      3.0
# 426                       Patel Nagar East, Patel Nagar      1.0
# 287                     Kailash Colony, Greater Kailash      1.0
# ...                                                 ...      ...
# 1243                                  Chittaranjan Park      5.0
# 1153                       Greater Kailash 4 Nri Colony      2.0
# 462                                Vasant Kunj Sector A      2.0
# 870               DDA Flats Pocket 6 Sector A10, Narela      2.0
# 391                         Virat Residency, Dwarka Mor      1.0
#
#              Status   Transaction           Type      Per_Sqft     Price
# 40    Ready_to_move        Resale  Builder_Floor  15690.136542  30000000
# 118   Ready_to_move        Resale  Builder_Floor  15556.000000  28000000
# 598   Ready_to_move  New_Property  Builder_Floor  23863.000000  52500000
# 426   Ready_to_move        Resale      Apartment  23840.000000  37500000
# 287   Ready_to_move        Resale  Builder_Floor  20833.000000  22500000
# ...             ...           ...            ...           ...       ...
# 1243  Ready_to_move  New_Property  Builder_Floor   6878.000000  35000000
# 1153  Ready_to_move        Resale  Builder_Floor  12500.000000  36500000
# 462   Ready_to_move        Resale      Apartment  20833.000000  25000000
# 870   Ready_to_move        Resale      Apartment   4889.000000   2200000
# 391   Ready_to_move  New_Property      Apartment   4620.000000   4620000
#
# [1007 rows x 11 columns]

# %%
train_data.hist(figsize = (15, 8))
# Out:
# array([[<Axes: title={'center': 'Area'}>,
#         <Axes: title={'center': 'BHK'}>],
#        [<Axes: title={'center': 'Bathroom'}>,
#         <Axes: title={'center': 'Parking'}>],
#        [<Axes: title={'center': 'Per_Sqft'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
train_data.corr()
# Out:
# <ipython-input-102-8d2cc80a8830>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_data.corr()
#               Area       BHK  Bathroom   Parking  Per_Sqft     Price
# Area      1.000000  0.443019  0.535757  0.002511  0.183373  0.571682
# BHK       0.443019  1.000000  0.764470 -0.045738  0.185663  0.570331
# Bathroom  0.535757  0.764470  1.000000 -0.013833  0.224035  0.735266
# Parking   0.002511 -0.045738 -0.013833  1.000000  0.015114  0.009151
# Per_Sqft  0.183373  0.185663  0.224035  0.015114  1.000000  0.357264
# Price     0.571682  0.570331  0.735266  0.009151  0.357264  1.000000

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <ipython-input-103-c1bf0ed2b00b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(), annot = True, cmap = 'YlGnBu')
# <Axes: >

# %%
train_data.Furnishing.value_counts()
# Out:
# Semi-Furnished    584
# Unfurnished       278
# Furnished         145
# Name: Furnishing, dtype: int64

# %%
train_data.Locality.value_counts()
# Out:
# Lajpat Nagar 2                                                                                                                                                                                                                                                                                                                                                      28
# J R Designers Floors, Rohini Sector 24                                                                                                                                                                                                                                                                                                                              26
# Yamuna Vihar, Shahdara                                                                                                                                                                                                                                                                                                                                              25
# Lajpat Nagar 3                                                                                                                                                                                                                                                                                                                                                      25
# Mehrauli                                                                                                                                                                                                                                                                                                                                                            23
#                                                                                                                                                                                                                                                                                                                                                                     ..
# DDA LIG Flat, Kalkaji                                                                                                                                                                                                                                                                                                                                                1
# Greater Kailash 2                                                                                                                                                                                                                                                                                                                                                    1
# Hauz Khas Apartment, Hauz Khas Enclave, Hauz Khas                                                                                                                                                                                                                                                                                                                    1
# Paschim Vihar How Auctions work? The borrower has the physical possession of the Property. However the lender (Bank) can legally sell the Property. carpet area 780 sqft status Ready to Move floor Ground out of 3 floors transaction Resale furnishing Unfurnished facing West bathroom 2 balcony 1 ownership Freehold Contact Now Enquire Now Auction By Bank     1
# Vasant Kunj Sector A                                                                                                                                                                                                                                                                                                                                                 1
# Name: Locality, Length: 331, dtype: int64

# %%
train_data.Status.value_counts()
# Out:
# Ready_to_move    947
# Almost_ready      60
# Name: Status, dtype: int64

# %%
train_data.Transaction.value_counts()
# Out:
# Resale          618
# New_Property    389
# Name: Transaction, dtype: int64

# %%
train_data.Type.value_counts()
# Out:
# Builder_Floor    532
# Apartment        475
# Name: Type, dtype: int64

# %%
train_data['Area'] = np.log(train_data['Area'] + 1)
train_data['Parking'] = np.log(train_data['Parking'] + 1)
train_data['Per_Sqft'] = np.log(train_data['Per_Sqft'] + 1)

# %%
train_data.hist(figsize = (15, 8))
# Out:
# array([[<Axes: title={'center': 'Area'}>,
#         <Axes: title={'center': 'BHK'}>],
#        [<Axes: title={'center': 'Bathroom'}>,
#         <Axes: title={'center': 'Parking'}>],
#        [<Axes: title={'center': 'Per_Sqft'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
train_data.corr()
# Out:
# <ipython-input-111-8d2cc80a8830>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_data.corr()
#               Area       BHK  Bathroom   Parking  Per_Sqft     Price
# Area      1.000000  0.652593  0.726784  0.192566  0.281390  0.663932
# BHK       0.652593  1.000000  0.764470  0.117144  0.258523  0.570331
# Bathroom  0.726784  0.764470  1.000000  0.203576  0.315201  0.735266
# Parking   0.192566  0.117144  0.203576  1.000000  0.198132  0.245030
# Per_Sqft  0.281390  0.258523  0.315201  0.198132  1.000000  0.422541
# Price     0.663932  0.570331  0.735266  0.245030  0.422541  1.000000

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <ipython-input-112-c1bf0ed2b00b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(), annot = True, cmap = 'YlGnBu')
# <Axes: >

# %%
train_data1 = train_data.join(pd.get_dummies(train_data.Furnishing)).drop(['Furnishing'], axis = 1)
train_data1
# Out:
#           Area  BHK  Bathroom  \
# 40    7.409136    3       3.0
# 118   7.438972    3       3.0
# 598   7.696667    4       4.0
# 426   7.601402    3       3.0
# 287   7.378384    3       3.0
# ...        ...  ...       ...
# 1243  7.409136    3       3.0
# 1153  7.901377    4       4.0
# 462   7.090910    3       2.0
# 870   6.111467    1       1.0
# 391   6.908755    3       2.0
#
#                                                Locality   Parking  \
# 40                                         Lajpat Nagar  0.693147
# 118                                      Lajpat Nagar 3  0.693147
# 598   Safdarjung Enclave super area 2200 sqft status...  1.386294
# 426                       Patel Nagar East, Patel Nagar  0.693147
# 287                     Kailash Colony, Greater Kailash  0.693147
# ...                                                 ...       ...
# 1243                                  Chittaranjan Park  1.791759
# 1153                       Greater Kailash 4 Nri Colony  1.098612
# 462                                Vasant Kunj Sector A  1.098612
# 870               DDA Flats Pocket 6 Sector A10, Narela  1.098612
# 391                         Virat Residency, Dwarka Mor  0.693147
#
#              Status   Transaction           Type   Per_Sqft     Price  \
# 40    Ready_to_move        Resale  Builder_Floor   9.660851  30000000
# 118   Ready_to_move        Resale  Builder_Floor   9.652266  28000000
# 598   Ready_to_move  New_Property  Builder_Floor  10.080126  52500000
# 426   Ready_to_move        Resale      Apartment  10.079162  37500000
# 287   Ready_to_move        Resale  Builder_Floor   9.944342  22500000
# ...             ...           ...            ...        ...       ...
# 1243  Ready_to_move  New_Property  Builder_Floor   8.836229  35000000
# 1153  Ready_to_move        Resale  Builder_Floor   9.433564  36500000
# 462   Ready_to_move        Resale      Apartment   9.944342  25000000
# 870   Ready_to_move        Resale      Apartment   8.494948   2200000
# 391   Ready_to_move  New_Property      Apartment   8.438366   4620000
#
#       Furnished  Semi-Furnished  Unfurnished
# 40            0               1            0
# 118           0               0            1
# 598           0               1            0
# 426           0               1            0
# 287           0               0            1
# ...         ...             ...          ...
# 1243          0               0            1
# 1153          0               0            1
# 462           0               1            0
# 870           1               0            0
# 391           0               0            1
#
# [1007 rows x 13 columns]

# %%
train_data2 = train_data1.join(pd.get_dummies(train_data.Status)).drop(["Status"], axis = 1)
train_data2
# Out:
#           Area  BHK  Bathroom  \
# 40    7.409136    3       3.0
# 118   7.438972    3       3.0
# 598   7.696667    4       4.0
# 426   7.601402    3       3.0
# 287   7.378384    3       3.0
# ...        ...  ...       ...
# 1243  7.409136    3       3.0
# 1153  7.901377    4       4.0
# 462   7.090910    3       2.0
# 870   6.111467    1       1.0
# 391   6.908755    3       2.0
#
#                                                Locality   Parking  \
# 40                                         Lajpat Nagar  0.693147
# 118                                      Lajpat Nagar 3  0.693147
# 598   Safdarjung Enclave super area 2200 sqft status...  1.386294
# 426                       Patel Nagar East, Patel Nagar  0.693147
# 287                     Kailash Colony, Greater Kailash  0.693147
# ...                                                 ...       ...
# 1243                                  Chittaranjan Park  1.791759
# 1153                       Greater Kailash 4 Nri Colony  1.098612
# 462                                Vasant Kunj Sector A  1.098612
# 870               DDA Flats Pocket 6 Sector A10, Narela  1.098612
# 391                         Virat Residency, Dwarka Mor  0.693147
#
#        Transaction           Type   Per_Sqft     Price  Furnished  \
# 40          Resale  Builder_Floor   9.660851  30000000          0
# 118         Resale  Builder_Floor   9.652266  28000000          0
# 598   New_Property  Builder_Floor  10.080126  52500000          0
# 426         Resale      Apartment  10.079162  37500000          0
# 287         Resale  Builder_Floor   9.944342  22500000          0
# ...            ...            ...        ...       ...        ...
# 1243  New_Property  Builder_Floor   8.836229  35000000          0
# 1153        Resale  Builder_Floor   9.433564  36500000          0
# 462         Resale      Apartment   9.944342  25000000          0
# 870         Resale      Apartment   8.494948   2200000          1
# 391   New_Property      Apartment   8.438366   4620000          0
#
#       Semi-Furnished  Unfurnished  Almost_ready  Ready_to_move
# 40                 1            0             0              1
# 118                0            1             0              1
# 598                1            0             0              1
# 426                1            0             0              1
# 287                0            1             0              1
# ...              ...          ...           ...            ...
# 1243               0            1             0              1
# 1153               0            1             0              1
# 462                1            0             0              1
# 870                0            0             0              1
# 391                0            1             0              1
#
# [1007 rows x 14 columns]

# %%
train_data3 = train_data2.join(pd.get_dummies(train_data.Transaction)).drop(["Transaction"], axis = 1)
train_data3
# Out:
#           Area  BHK  Bathroom  \
# 40    7.409136    3       3.0
# 118   7.438972    3       3.0
# 598   7.696667    4       4.0
# 426   7.601402    3       3.0
# 287   7.378384    3       3.0
# ...        ...  ...       ...
# 1243  7.409136    3       3.0
# 1153  7.901377    4       4.0
# 462   7.090910    3       2.0
# 870   6.111467    1       1.0
# 391   6.908755    3       2.0
#
#                                                Locality   Parking  \
# 40                                         Lajpat Nagar  0.693147
# 118                                      Lajpat Nagar 3  0.693147
# 598   Safdarjung Enclave super area 2200 sqft status...  1.386294
# 426                       Patel Nagar East, Patel Nagar  0.693147
# 287                     Kailash Colony, Greater Kailash  0.693147
# ...                                                 ...       ...
# 1243                                  Chittaranjan Park  1.791759
# 1153                       Greater Kailash 4 Nri Colony  1.098612
# 462                                Vasant Kunj Sector A  1.098612
# 870               DDA Flats Pocket 6 Sector A10, Narela  1.098612
# 391                         Virat Residency, Dwarka Mor  0.693147
#
#                Type   Per_Sqft     Price  Furnished  Semi-Furnished  \
# 40    Builder_Floor   9.660851  30000000          0               1
# 118   Builder_Floor   9.652266  28000000          0               0
# 598   Builder_Floor  10.080126  52500000          0               1
# 426       Apartment  10.079162  37500000          0               1
# 287   Builder_Floor   9.944342  22500000          0               0
# ...             ...        ...       ...        ...             ...
# 1243  Builder_Floor   8.836229  35000000          0               0
# 1153  Builder_Floor   9.433564  36500000          0               0
# 462       Apartment   9.944342  25000000          0               1
# 870       Apartment   8.494948   2200000          1               0
# 391       Apartment   8.438366   4620000          0               0
#
#       Unfurnished  Almost_ready  Ready_to_move  New_Property  Resale
# 40              0             0              1             0       1
# 118             1             0              1             0       1
# 598             0             0              1             1       0
# 426             0             0              1             0       1
# 287             1             0              1             0       1
# ...           ...           ...            ...           ...     ...
# 1243            1             0              1             1       0
# 1153            1             0              1             0       1
# 462             0             0              1             0       1
# 870             0             0              1             0       1
# 391             1             0              1             1       0
#
# [1007 rows x 15 columns]

# %%
train_data4 = train_data3.join(pd.get_dummies(train_data.Type)).drop(["Type"], axis = 1)
train_data4
# Out:
#           Area  BHK  Bathroom  \
# 40    7.409136    3       3.0
# 118   7.438972    3       3.0
# 598   7.696667    4       4.0
# 426   7.601402    3       3.0
# 287   7.378384    3       3.0
# ...        ...  ...       ...
# 1243  7.409136    3       3.0
# 1153  7.901377    4       4.0
# 462   7.090910    3       2.0
# 870   6.111467    1       1.0
# 391   6.908755    3       2.0
#
#                                                Locality   Parking   Per_Sqft  \
# 40                                         Lajpat Nagar  0.693147   9.660851
# 118                                      Lajpat Nagar 3  0.693147   9.652266
# 598   Safdarjung Enclave super area 2200 sqft status...  1.386294  10.080126
# 426                       Patel Nagar East, Patel Nagar  0.693147  10.079162
# 287                     Kailash Colony, Greater Kailash  0.693147   9.944342
# ...                                                 ...       ...        ...
# 1243                                  Chittaranjan Park  1.791759   8.836229
# 1153                       Greater Kailash 4 Nri Colony  1.098612   9.433564
# 462                                Vasant Kunj Sector A  1.098612   9.944342
# 870               DDA Flats Pocket 6 Sector A10, Narela  1.098612   8.494948
# 391                         Virat Residency, Dwarka Mor  0.693147   8.438366
#
#          Price  Furnished  Semi-Furnished  Unfurnished  Almost_ready  \
# 40    30000000          0               1            0             0
# 118   28000000          0               0            1             0
# 598   52500000          0               1            0             0
# 426   37500000          0               1            0             0
# 287   22500000          0               0            1             0
# ...        ...        ...             ...          ...           ...
# 1243  35000000          0               0            1             0
# 1153  36500000          0               0            1             0
# 462   25000000          0               1            0             0
# 870    2200000          1               0            0             0
# 391    4620000          0               0            1             0
#
#       Ready_to_move  New_Property  Resale  Apartment  Builder_Floor
# 40                1             0       1          0              1
# 118               1             0       1          0              1
# 598               1             1       0          0              1
# 426               1             0       1          1              0
# 287               1             0       1          0              1
# ...             ...           ...     ...        ...            ...
# 1243              1             1       0          0              1
# 1153              1             0       1          0              1
# 462               1             0       1          1              0
# 870               1             0       1          1              0
# 391               1             1       0          1              0
#
# [1007 rows x 16 columns]

# %%
train_data_ready = train_data4.drop(["Locality"], axis = 1)
train_data_ready
# Out:
#           Area  BHK  Bathroom   Parking   Per_Sqft     Price  Furnished  \
# 40    7.409136    3       3.0  0.693147   9.660851  30000000          0
# 118   7.438972    3       3.0  0.693147   9.652266  28000000          0
# 598   7.696667    4       4.0  1.386294  10.080126  52500000          0
# 426   7.601402    3       3.0  0.693147  10.079162  37500000          0
# 287   7.378384    3       3.0  0.693147   9.944342  22500000          0
# ...        ...  ...       ...       ...        ...       ...        ...
# 1243  7.409136    3       3.0  1.791759   8.836229  35000000          0
# 1153  7.901377    4       4.0  1.098612   9.433564  36500000          0
# 462   7.090910    3       2.0  1.098612   9.944342  25000000          0
# 870   6.111467    1       1.0  1.098612   8.494948   2200000          1
# 391   6.908755    3       2.0  0.693147   8.438366   4620000          0
#
#       Semi-Furnished  Unfurnished  Almost_ready  Ready_to_move  New_Property  \
# 40                 1            0             0              1             0
# 118                0            1             0              1             0
# 598                1            0             0              1             1
# 426                1            0             0              1             0
# 287                0            1             0              1             0
# ...              ...          ...           ...            ...           ...
# 1243               0            1             0              1             1
# 1153               0            1             0              1             0
# 462                1            0             0              1             0
# 870                0            0             0              1             0
# 391                0            1             0              1             1
#
#       Resale  Apartment  Builder_Floor
# 40         1          0              1
# 118        1          0              1
# 598        0          0              1
# 426        1          1              0
# 287        1          0              1
# ...      ...        ...            ...
# 1243       0          0              1
# 1153       1          0              1
# 462        1          1              0
# 870        1          1              0
# 391        0          1              0
#
# [1007 rows x 15 columns]

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data_ready.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(x = 'Area', y = 'BHK', data =train_data_ready, hue = 'Price', palette = 'coolwarm')
# Out:
# <Axes: xlabel='Area', ylabel='BHK'>

# %%
train_data_ready['BHK Ration'] = train_data_ready['BHK'] / train_data_ready['Area']
train_data_ready['Bathroom Ratio'] = train_data_ready['Bathroom'] / train_data_ready['BHK']

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data_ready.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train, y_train = train_data_ready.drop(["Price"], axis = 1), train_data_ready['Price']
x_train_s = scaler.fit_transform(x_train)

reg = LinearRegression()
reg.fit(x_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)
test_data['Area'] = np.log(test_data['Area'] + 1)
test_data['Parking'] = np.log(test_data['Parking'] + 1)
test_data['Per_Sqft'] = np.log(test_data['Per_Sqft'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.Furnishing)).drop(['Furnishing'], axis = 1)

test_data = test_data.join(pd.get_dummies(test_data.Status)).drop(["Status"], axis = 1)

test_data = test_data.join(pd.get_dummies(test_data.Transaction)).drop(["Transaction"], axis = 1)

test_data = test_data.join(pd.get_dummies(test_data.Type)).drop(["Type"], axis = 1)

test_data = test_data.drop(["Locality"], axis = 1)


test_data['BHK Ration'] = test_data['BHK'] / test_data['Area']
test_data['Bathroom Ratio'] = test_data['Bathroom'] / test_data['BHK']

x_test, y_test = test_data.drop(["Price"], axis = 1), test_data['Price']

# %%
x_test_s = scaler.transform(x_test)

# %%
reg.score(x_test_s, y_test)
# Out:
# 0.5563467669194485

# %%
test_data
# Out:
#           Area  BHK  Bathroom   Parking   Per_Sqft      Price  Furnished  \
# 961   6.957497    2       2.0  0.693147   9.660851    9000000          0
# 63    7.235619    4       4.0  0.693147   8.354204    5890000          0
# 1056  7.131699    2       2.0  1.098612   9.660851   15000000          1
# 1032  7.155396    3       3.0  1.098612   9.553433   15000000          1
# 1258  9.310276    3       3.0  0.693147   9.466300   18500000          0
# ...        ...  ...       ...       ...        ...        ...        ...
# 1057  7.937732    4       4.0  1.098612   9.567035   40000000          0
# 638   7.378384    3       2.0  0.693147   9.660851   15800000          0
# 495   8.522380    5       6.0  1.609438  10.008883  170000000          0
# 1100  6.447306    2       2.0  0.693147  11.093082    4600000          0
# 668   7.612337    3       3.0  1.098612   9.841293   38000000          0
#
#       Semi-Furnished  Unfurnished  Almost_ready  Ready_to_move  New_Property  \
# 961                1            0             0              1             0
# 63                 0            1             0              1             1
# 1056               0            0             0              1             0
# 1032               0            0             0              1             0
# 1258               0            1             0              1             1
# ...              ...          ...           ...            ...           ...
# 1057               0            1             0              1             0
# 638                1            0             0              1             0
# 495                0            1             1              0             1
# 1100               1            0             0              1             0
# 668                1            0             0              1             0
#
#       Resale  Apartment  Builder_Floor  BHK Ration  Bathroom Ratio
# 961        1          1              0    0.287460        1.000000
# 63         0          1              0    0.552821        1.000000
# 1056       1          1              0    0.280438        1.000000
# 1032       1          0              1    0.419264        1.000000
# 1258       0          0              1    0.322225        1.000000
# ...      ...        ...            ...         ...             ...
# 1057       1          1              0    0.503922        1.000000
# 638        1          1              0    0.406593        0.666667
# 495        0          0              1    0.586691        1.200000
# 1100       1          0              1    0.310207        1.000000
# 668        1          1              0    0.394097        1.000000
#
# [252 rows x 17 columns]

# %%
reg.score(x_test,  y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -24.26552802026494

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.9027009441554108

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [30, 50, 100],
    "max_features": [6, 8, 12],
    "min_samples_split": [2,4,6,8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                          scoring="neg_mean_squared_error",
                          return_train_score=True)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [6, 8, 12],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [30, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_
best_forest
# Out:
# RandomForestRegressor(max_features=12, min_samples_split=4, n_estimators=50)

# %%
best_forest.score(x_test, y_test)
# Out:
# 0.8825302626003526
